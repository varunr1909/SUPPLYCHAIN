# %%
# import Data manipulation library
import numpy as np
import pandas as pd
# import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
#import data filter warning
import warnings
warnings.filterwarnings('ignore')

# %%
# import data using url  from github
url = 'https://raw.githubusercontent.com/varunr1909/SUPPLYCHAIN/refs/heads/main/SCM.csv'
df = pd.read_csv(url)
df.sample(frac=1)
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 18051     WH_118051     EID_68051         Rural              Mid  South
# 17557     WH_117557     EID_67557         Rural            Small   West
# 21609     WH_121609     EID_71609         Rural              Mid  South
# 5910      WH_105910     EID_55910         Rural              Mid  South
# 12334     WH_112334     EID_62334         Rural              Mid  South
# ...             ...           ...           ...              ...    ...
# 13743     WH_113743     EID_63743         Rural            Small   West
# 19607     WH_119607     EID_69607         Rural              Mid  North
# 14927     WH_114927     EID_64927         Rural            Large  North
# 17959     WH_117959     EID_67959         Rural            Large  South
# 4185      WH_104185     EID_54185         Rural              Mid   West
#
#       WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# 18051           Zone 4                   1                    0
# 17557           Zone 1                   6                    0
# 21609           Zone 2                   0                    2
# 5910            Zone 3                   2                    0
# 12334           Zone 2                   8                    0
# ...                ...                 ...                  ...
# 13743           Zone 6                   0                    0
# 19607           Zone 4                   0                    1
# 14927           Zone 6                   0                    0
# 17959           Zone 5                   3                    1
# 4185            Zone 2                   3                    0
#
#        Competitor_in_mkt  retail_shop_num  ... electric_supply  dist_from_hub  \
# 18051                  2             6013  ...               1            183
# 17557                  2             4519  ...               1            193
# 21609                  2             5446  ...               1             56
# 5910                   2             5141  ...               0            145
# 12334                  2             4834  ...               0            102
# ...                  ...              ...  ...             ...            ...
# 13743                  4             4866  ...               1            217
# 19607                  3             5806  ...               1             70
# 14927                  3             2846  ...               1            122
# 17959                  2             4572  ...               1            260
# 4185                   2             4681  ...               1            226
#
#        workers_num  wh_est_year  storage_issue_reported_l3m  temp_reg_mach  \
# 18051         33.0          NaN                          22              1
# 17557         34.0       2012.0                          19              0
# 21609         37.0          NaN                           9              0
# 5910          28.0          NaN                           6              1
# 12334         26.0          NaN                          26              0
# ...            ...          ...                         ...            ...
# 13743         45.0          NaN                           8              0
# 19607          NaN          NaN                          18              0
# 14927         39.0          NaN                          19              0
# 17959         30.0       2002.0                          23              0
# 4185          33.0       2006.0                          15              1
#
#        approved_wh_govt_certificate  wh_breakdown_l3m  govt_check_l3m  \
# 18051                             A                 4              26
# 17557                             A                 4              30
# 21609                             B                 4              32
# 5910                             A+                 3              27
# 12334                            B+                 3               1
# ...                             ...               ...             ...
# 13743                            B+                 3               9
# 19607                             B                 2              26
# 14927                            A+                 1               6
# 17959                             C                 5              10
# 4185                              A                 2               1
#
#        product_wg_ton
# 18051           28145
# 17557           24065
# 21609           11055
# 5910             8056
# 12334           30122
# ...               ...
# 13743            9073
# 19607           21068
# 14927           27139
# 17959           30090
# 4185            20088
#
# [22150 rows x 24 columns]

# %%
#CHECKING INFORMATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22150 entries, 0 to 22149
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ware_house_ID                 22150 non-null  object
#  1   WH_Manager_ID                 22150 non-null  object
#  2   Location_type                 22150 non-null  object
#  3   WH_capacity_size              22150 non-null  object
#  4   zone                          22150 non-null  object
#  5   WH_regional_zone              22150 non-null  object
#  6   num_refill_req_l3m            22150 non-null  int64
#  7   transport_issue_l1y           22150 non-null  int64
#  8   Competitor_in_mkt             22150 non-null  int64
#  9   retail_shop_num               22150 non-null  int64
#  10  wh_owner_type                 22150 non-null  object
#  11  distributor_num               22150 non-null  int64
#  12  flood_impacted                22150 non-null  int64
#  13  flood_proof                   22150 non-null  int64
#  14  electric_supply               22150 non-null  int64
#  15  dist_from_hub                 22150 non-null  int64
#  16  workers_num                   21273 non-null  float64
#  17  wh_est_year                   11605 non-null  float64
#  18  storage_issue_reported_l3m    22150 non-null  int64
#  19  temp_reg_mach                 22150 non-null  int64
#  20  approved_wh_govt_certificate  21345 non-null  object
#  21  wh_breakdown_l3m              22150 non-null  int64
#  22  govt_check_l3m                22150 non-null  int64
#  23  product_wg_ton                22150 non-null  int64
# dtypes: float64(2), int64(14), object(8)
# memory usage: 4.1+ MB

# %%
df['workers_num'].isnull().sum()/len(df['workers_num'])*100
# null value is acceptable upto 5% and >15% it is critical stage
# Out:
# 3.959367945823928

# %%
df['workers_num'].median()
# Out:
# 28.0

# %%
df['workers_num'].mean()
# Out:
# 28.93639825130447

# %%
df['workers_num'].quantile(0.75),df['workers_num'].quantile(0.25)
# Out:
# (33.0, 24.0)

# %%
#IMPUTE ONLY INTEGER VALUE WHEN VALUE IS NULL WHICH IS MEAN , MEDIAN OR IQR
df['workers_num'].fillna(28,inplace = True )

# %%
df.isnull().sum()
# Out:
# Location_type                   0
# WH_capacity_size                0
# zone                            0
# WH_regional_zone                0
# num_refill_req_l3m              0
# transport_issue_l1y             0
# Competitor_in_mkt               0
# retail_shop_num                 0
# wh_owner_type                   0
# distributor_num                 0
# flood_impacted                  0
# flood_proof                     0
# electric_supply                 0
# dist_from_hub                   0
# workers_num                     0
# wh_est_year                     0
# storage_issue_reported_l3m      0
# temp_reg_mach                   0
# approved_wh_govt_certificate    0
# wh_breakdown_l3m                0
# govt_check_l3m                  0
# product_wg_ton                  0
# dtype: int64

# %%
df['wh_est_year'].fillna('2000',inplace=True)

# %%
df['wh_est_year'].mode()
# Out:
# 0    2000
# Name: wh_est_year, dtype: object

# %%
df['approved_wh_govt_certificate'].fillna('C',inplace= True)

# %%
# seprate categorical and numerical columns 
categorical_columns = df.select_dtypes(include = 'object')

# %%
numerical_columns = df.select_dtypes(exclude = 'object')

# %%
categorical_columns
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 0         WH_100000     EID_50000         Urban            Small   West
# 1         WH_100001     EID_50001         Rural            Large  North
# 2         WH_100002     EID_50002         Rural              Mid  South
# 3         WH_100003     EID_50003         Rural              Mid  North
# 4         WH_100004     EID_50004         Rural            Large  North
# ...             ...           ...           ...              ...    ...
# 22145     WH_122145     EID_72145         Rural            Large  North
# 22146     WH_122146     EID_72146         Rural            Small  South
# 22147     WH_122147     EID_72147         Rural            Large  North
# 22148     WH_122148     EID_72148         Rural            Large  North
# 22149     WH_122149     EID_72149         Rural              Mid   East
#
#       WH_regional_zone  wh_owner_type wh_est_year approved_wh_govt_certificate
# 0               Zone 6         Rented        2000                            A
# 1               Zone 5  Company Owned        2000                            A
# 2               Zone 2  Company Owned        2000                            A
# 3               Zone 3         Rented        2000                           A+
# 4               Zone 5  Company Owned      2009.0                            C
# ...                ...            ...         ...                          ...
# 22145           Zone 6         Rented      2007.0                           A+
# 22146           Zone 6         Rented        2000                            C
# 22147           Zone 6  Company Owned        2000                           B+
# 22148           Zone 6         Rented        2000                            B
# 22149           Zone 4  Company Owned        2000                            C
#
# [22150 rows x 9 columns]

# %%
df.drop(columns=['Ware_house_ID','WH_Manager_ID'],inplace= True)

# %%
df.head()
# Out:
#   Location_type WH_capacity_size   zone WH_regional_zone  num_refill_req_l3m  \
# 0         Urban            Small   West           Zone 6                   3
# 1         Rural            Large  North           Zone 5                   0
# 2         Rural              Mid  South           Zone 2                   1
# 3         Rural              Mid  North           Zone 3                   7
# 4         Rural            Large  North           Zone 5                   3
#
#    transport_issue_l1y  Competitor_in_mkt  retail_shop_num  wh_owner_type  \
# 0                    1                  2             4651         Rented
# 1                    0                  4             6217  Company Owned
# 2                    0                  4             4306  Company Owned
# 3                    4                  2             6000         Rented
# 4                    1                  2             4740  Company Owned
#
#    distributor_num  ...  electric_supply  dist_from_hub  workers_num  \
# 0               24  ...                1             91         29.0
# 1               47  ...                1            210         31.0
# 2               64  ...                0            161         37.0
# 3               50  ...                0            103         21.0
# 4               42  ...                1            112         25.0
#
#    wh_est_year  storage_issue_reported_l3m temp_reg_mach  \
# 0         2000                          13             0
# 1         2000                           4             0
# 2         2000                          17             0
# 3         2000                          17             1
# 4       2009.0                          18             0
#
#    approved_wh_govt_certificate  wh_breakdown_l3m govt_check_l3m  \
# 0                             A                 5             15
# 1                             A                 3             17
# 2                             A                 6             22
# 3                            A+                 3             27
# 4                             C                 6             24
#
#    product_wg_ton
# 0           17115
# 1            5074
# 2           23137
# 3           22115
# 4           24071
#
# [5 rows x 22 columns]

# %%
#evaluate the data for west zone 
df[df['zone']=='West']
# Out:
#       Location_type WH_capacity_size  zone WH_regional_zone  \
# 0             Urban            Small  West           Zone 6
# 5             Rural            Small  West           Zone 1
# 6             Rural            Large  West           Zone 6
# 14            Rural            Small  West           Zone 6
# 16            Rural              Mid  West           Zone 4
# ...             ...              ...   ...              ...
# 22119         Rural            Large  West           Zone 6
# 22138         Rural              Mid  West           Zone 4
# 22139         Rural              Mid  West           Zone 3
# 22140         Rural            Large  West           Zone 5
# 22143         Rural            Large  West           Zone 5
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                       3                    1                  2
# 5                       8                    0                  2
# 6                       8                    0                  4
# 14                      8                    1                  4
# 16                      0                    0                  2
# ...                   ...                  ...                ...
# 22119                   8                    0                  4
# 22138                   7                    0                  3
# 22139                   5                    0                  4
# 22140                   7                    0                  4
# 22143                   1                    0                  2
#
#        retail_shop_num  wh_owner_type  distributor_num  ...  electric_supply  \
# 0                 4651         Rented               24  ...                1
# 5                 5053         Rented               37  ...                1
# 6                 4449  Company Owned               38  ...                1
# 14                5022         Rented               68  ...                1
# 16                5569  Company Owned               16  ...                1
# ...                ...            ...              ...  ...              ...
# 22119             4687         Rented               62  ...                1
# 22138             4686  Company Owned               55  ...                1
# 22139             3771         Rented               66  ...                0
# 22140             4593         Rented               18  ...                1
# 22143             5415         Rented               27  ...                1
#
#        dist_from_hub  workers_num  wh_est_year  storage_issue_reported_l3m  \
# 0                 91         29.0         2000                          13
# 5                152         35.0       2009.0                          23
# 6                 77         27.0       2010.0                          24
# 14               129         37.0         2000                           6
# 16               231         28.0         2000                           9
# ...              ...          ...          ...                         ...
# 22119            160         26.0       2005.0                          32
# 22138            148         28.0       2010.0                          23
# 22139             97         30.0       1998.0                          24
# 22140             78         24.0       2008.0                          18
# 22143            231         32.0         2000                           0
#
#       temp_reg_mach  approved_wh_govt_certificate  wh_breakdown_l3m  \
# 0                 0                             A                 5
# 5                 1                            A+                 3
# 6                 0                             B                 3
# 14                0                             B                 3
# 16                0                            B+                 5
# ...             ...                           ...               ...
# 22119             0                             B                 3
# 22138             0                            B+                 6
# 22139             0                             C                 2
# 22140             0                            B+                 6
# 22143             0                             C                 0
#
#       govt_check_l3m  product_wg_ton
# 0                 15           17115
# 5                  3           32134
# 6                  6           30142
# 14                 9            7055
# 16                11           12127
# ...              ...             ...
# 22119             23           40086
# 22138             11           29130
# 22139             19           30102
# 22140             14           21128
# 22143             24            3133
#
# [7055 rows x 22 columns]

# %%
df['zone'].value_counts().plot(kind = 'pie',autopct = '%1.2f',explode = [0.01,0.01,0.01,0.01])
# Out:
# <Axes: ylabel='count'>

# %%
southzone = df[df['zone']=='South']

# %%
southzone
# Out:
#       Location_type WH_capacity_size   zone WH_regional_zone  \
# 2             Rural              Mid  South           Zone 2
# 8             Rural            Small  South           Zone 6
# 9             Rural            Small  South           Zone 6
# 13            Rural              Mid  South           Zone 4
# 19            Rural            Small  South           Zone 1
# ...             ...              ...    ...              ...
# 22133         Rural            Large  South           Zone 5
# 22135         Urban            Large  South           Zone 5
# 22136         Urban            Small  South           Zone 1
# 22144         Rural            Small  South           Zone 6
# 22146         Rural            Small  South           Zone 6
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 2                       1                    0                  4
# 8                       8                    1                  4
# 9                       4                    3                  3
# 13                      6                    1                  2
# 19                      1                    1                  2
# ...                   ...                  ...                ...
# 22133                   7                    0                  2
# 22135                   8                    0                  4
# 22136                   3                    1                  2
# 22144                   1                    2                  3
# 22146                   3                    1                  3
#
#        retail_shop_num  wh_owner_type  distributor_num  ...  electric_supply  \
# 2                 4306  Company Owned               64  ...                0
# 8                 5381         Rented               42  ...                1
# 9                 3869  Company Owned               35  ...                0
# 13                6858  Company Owned               26  ...                1
# 19                5679         Rented               19  ...                1
# ...                ...            ...              ...  ...              ...
# 22133             5114  Company Owned               30  ...                0
# 22135             4312         Rented               19  ...                0
# 22136             5792         Rented               43  ...                0
# 22144             3325  Company Owned               22  ...                1
# 22146             4320         Rented               60  ...                0
#
#        dist_from_hub  workers_num  wh_est_year  storage_issue_reported_l3m  \
# 2                161         37.0         2000                          17
# 8                124         22.0       2013.0                          13
# 9                 78         43.0         2000                           6
# 13               242         36.0       2008.0                          22
# 19               189         24.0         2000                          22
# ...              ...          ...          ...                         ...
# 22133             85         33.0         2000                          14
# 22135            194         21.0       2014.0                          19
# 22136            217         21.0       2012.0                          19
# 22144            160         37.0         2000                           9
# 22146            170         28.0         2000                          26
#
#       temp_reg_mach  approved_wh_govt_certificate  wh_breakdown_l3m  \
# 2                 0                             A                 6
# 8                 1                            A+                 5
# 9                 0                             C                 6
# 13                1                             A                 5
# 19                0                             B                 2
# ...             ...                           ...               ...
# 22133             0                             B                 5
# 22135             1                             A                 2
# 22136             0                             B                 2
# 22144             0                             B                 5
# 22146             0                             C                 5
#
#       govt_check_l3m  product_wg_ton
# 2                 22           23137
# 8                  2           18082
# 9                  2            7130
# 13                11           30063
# 19                21           27100
# ...              ...             ...
# 22133             10           16063
# 22135             25           26114
# 22136             31           22082
# 22144              9           10068
# 22146              9           33108
#
# [5644 rows x 22 columns]

# %%
categorical_columns
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 0         WH_100000     EID_50000         Urban            Small   West
# 1         WH_100001     EID_50001         Rural            Large  North
# 2         WH_100002     EID_50002         Rural              Mid  South
# 3         WH_100003     EID_50003         Rural              Mid  North
# 4         WH_100004     EID_50004         Rural            Large  North
# ...             ...           ...           ...              ...    ...
# 22145     WH_122145     EID_72145         Rural            Large  North
# 22146     WH_122146     EID_72146         Rural            Small  South
# 22147     WH_122147     EID_72147         Rural            Large  North
# 22148     WH_122148     EID_72148         Rural            Large  North
# 22149     WH_122149     EID_72149         Rural              Mid   East
#
#       WH_regional_zone  wh_owner_type wh_est_year approved_wh_govt_certificate
# 0               Zone 6         Rented        2000                            A
# 1               Zone 5  Company Owned        2000                            A
# 2               Zone 2  Company Owned        2000                            A
# 3               Zone 3         Rented        2000                           A+
# 4               Zone 5  Company Owned      2009.0                            C
# ...                ...            ...         ...                          ...
# 22145           Zone 6         Rented      2007.0                           A+
# 22146           Zone 6         Rented        2000                            C
# 22147           Zone 6  Company Owned        2000                           B+
# 22148           Zone 6         Rented        2000                            B
# 22149           Zone 4  Company Owned        2000                            C
#
# [22150 rows x 9 columns]

# %%
df['Location_type'].value_counts()
# Out:
# Location_type
# Rural    20334
# Urban     1816
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Location_type']= le.fit_transform(df['Location_type'])

# %%
df['Location_type'].value_counts()
# Out:
# Location_type
# 0    20334
# 1     1816
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['WH_capacity_size']= le.fit_transform(df['WH_capacity_size'])

# %%
df['WH_capacity_size'].value_counts()
# Out:
# WH_capacity_size
# 0    8968
# 1    8902
# 2    4280
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22150 entries, 0 to 22149
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Location_type                 22150 non-null  int32
#  1   WH_capacity_size              22150 non-null  int32
#  2   zone                          22150 non-null  object
#  3   WH_regional_zone              22150 non-null  object
#  4   num_refill_req_l3m            22150 non-null  int64
#  5   transport_issue_l1y           22150 non-null  int64
#  6   Competitor_in_mkt             22150 non-null  int64
#  7   retail_shop_num               22150 non-null  int64
#  8   wh_owner_type                 22150 non-null  object
#  9   distributor_num               22150 non-null  int64
#  10  flood_impacted                22150 non-null  int64
#  11  flood_proof                   22150 non-null  int64
#  12  electric_supply               22150 non-null  int64
#  13  dist_from_hub                 22150 non-null  int64
#  14  workers_num                   22150 non-null  float64
#  15  wh_est_year                   22150 non-null  object
#  16  storage_issue_reported_l3m    22150 non-null  int64
#  17  temp_reg_mach                 22150 non-null  int64
#  18  approved_wh_govt_certificate  22150 non-null  object
#  19  wh_breakdown_l3m              22150 non-null  int64
#  20  govt_check_l3m                22150 non-null  int64
#  21  product_wg_ton                22150 non-null  int64
# dtypes: float64(1), int32(2), int64(14), object(5)
# memory usage: 3.5+ MB

# %%
southzone
# Out:
#       Location_type WH_capacity_size   zone WH_regional_zone  \
# 2             Rural              Mid  South           Zone 2
# 8             Rural            Small  South           Zone 6
# 9             Rural            Small  South           Zone 6
# 13            Rural              Mid  South           Zone 4
# 19            Rural            Small  South           Zone 1
# ...             ...              ...    ...              ...
# 22133         Rural            Large  South           Zone 5
# 22135         Urban            Large  South           Zone 5
# 22136         Urban            Small  South           Zone 1
# 22144         Rural            Small  South           Zone 6
# 22146         Rural            Small  South           Zone 6
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 2                       1                    0                  4
# 8                       8                    1                  4
# 9                       4                    3                  3
# 13                      6                    1                  2
# 19                      1                    1                  2
# ...                   ...                  ...                ...
# 22133                   7                    0                  2
# 22135                   8                    0                  4
# 22136                   3                    1                  2
# 22144                   1                    2                  3
# 22146                   3                    1                  3
#
#        retail_shop_num  wh_owner_type  distributor_num  ...  electric_supply  \
# 2                 4306  Company Owned               64  ...                0
# 8                 5381         Rented               42  ...                1
# 9                 3869  Company Owned               35  ...                0
# 13                6858  Company Owned               26  ...                1
# 19                5679         Rented               19  ...                1
# ...                ...            ...              ...  ...              ...
# 22133             5114  Company Owned               30  ...                0
# 22135             4312         Rented               19  ...                0
# 22136             5792         Rented               43  ...                0
# 22144             3325  Company Owned               22  ...                1
# 22146             4320         Rented               60  ...                0
#
#        dist_from_hub  workers_num  wh_est_year  storage_issue_reported_l3m  \
# 2                161         37.0         2000                          17
# 8                124         22.0       2013.0                          13
# 9                 78         43.0         2000                           6
# 13               242         36.0       2008.0                          22
# 19               189         24.0         2000                          22
# ...              ...          ...          ...                         ...
# 22133             85         33.0         2000                          14
# 22135            194         21.0       2014.0                          19
# 22136            217         21.0       2012.0                          19
# 22144            160         37.0         2000                           9
# 22146            170         28.0         2000                          26
#
#       temp_reg_mach  approved_wh_govt_certificate  wh_breakdown_l3m  \
# 2                 0                             A                 6
# 8                 1                            A+                 5
# 9                 0                             C                 6
# 13                1                             A                 5
# 19                0                             B                 2
# ...             ...                           ...               ...
# 22133             0                             B                 5
# 22135             1                             A                 2
# 22136             0                             B                 2
# 22144             0                             B                 5
# 22146             0                             C                 5
#
#       govt_check_l3m  product_wg_ton
# 2                 22           23137
# 8                  2           18082
# 9                  2            7130
# 13                11           30063
# 19                21           27100
# ...              ...             ...
# 22133             10           16063
# 22135             25           26114
# 22136             31           22082
# 22144              9           10068
# 22146              9           33108
#
# [5644 rows x 22 columns]

# %%
df
# Out:
#        Location_type  WH_capacity_size   zone WH_regional_zone  \
# 0                  1                 2   West           Zone 6
# 1                  0                 0  North           Zone 5
# 2                  0                 1  South           Zone 2
# 3                  0                 1  North           Zone 3
# 4                  0                 0  North           Zone 5
# ...              ...               ...    ...              ...
# 22145              0                 0  North           Zone 6
# 22146              0                 2  South           Zone 6
# 22147              0                 0  North           Zone 6
# 22148              0                 0  North           Zone 6
# 22149              0                 1   East           Zone 4
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                       3                    1                  2
# 1                       0                    0                  4
# 2                       1                    0                  4
# 3                       7                    4                  2
# 4                       3                    1                  2
# ...                   ...                  ...                ...
# 22145                   8                    1                  3
# 22146                   3                    1                  3
# 22147                   7                    2                  2
# 22148                   6                    2                  4
# 22149                   7                    2                  9
#
#        retail_shop_num  wh_owner_type  distributor_num  ...  electric_supply  \
# 0                 4651         Rented               24  ...                1
# 1                 6217  Company Owned               47  ...                1
# 2                 4306  Company Owned               64  ...                0
# 3                 6000         Rented               50  ...                0
# 4                 4740  Company Owned               42  ...                1
# ...                ...            ...              ...  ...              ...
# 22145             5030         Rented               46  ...                1
# 22146             4320         Rented               60  ...                0
# 22147             5268  Company Owned               64  ...                0
# 22148             4378         Rented               32  ...                0
# 22149             3626  Company Owned               50  ...                1
#
#        dist_from_hub  workers_num  wh_est_year  storage_issue_reported_l3m  \
# 0                 91         29.0         2000                          13
# 1                210         31.0         2000                           4
# 2                161         37.0         2000                          17
# 3                103         21.0         2000                          17
# 4                112         25.0       2009.0                          18
# ...              ...          ...          ...                         ...
# 22145            203         28.0       2007.0                          22
# 22146            170         28.0         2000                          26
# 22147             99         22.0         2000                          20
# 22148            220         17.0         2000                          13
# 22149            104         36.0         2000                          11
#
#       temp_reg_mach  approved_wh_govt_certificate  wh_breakdown_l3m  \
# 0                 0                             A                 5
# 1                 0                             A                 3
# 2                 0                             A                 6
# 3                 1                            A+                 3
# 4                 0                             C                 6
# ...             ...                           ...               ...
# 22145             1                            A+                 2
# 22146             0                             C                 5
# 22147             0                            B+                 6
# 22148             0                             B                 3
# 22149             0                             C                 6
#
#       govt_check_l3m  product_wg_ton
# 0                 15           17115
# 1                 17            5074
# 2                 22           23137
# 3                 27           22115
# 4                 24           24071
# ...              ...             ...
# 22145              4           29138
# 22146              9           33108
# 22147              4           24072
# 22148             28           15055
# 22149             26           14103
#
# [22150 rows x 22 columns]
